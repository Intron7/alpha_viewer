# %%
from alpha_viewer import alpha_viewer

# %%
viewer = alpha_viewer("ptm/saci_RS06010/")
# Out:
# using model: model_3_ptm_pred_0 with pLDDT 83.11150542476875

# %%
viewer.plot_pLDDT(save=True)

# %%
viewer.plot_pae(save=True)

# %%
viewer.show_confidence()
# Out:
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
viewer.show_glycosylation()
# Out:
# Error: File does not appear to exist. Please create a `glyc.txt` in the alphafold output folder.
