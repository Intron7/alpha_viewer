# %%
from alpha_viewer import alpha_viewer

# %%
viewer = alpha_viewer("output_2/LacS-TGP_oldlinker/")
# Out:
# using model: model_1_ptm with pLDDT 93.61416556795625

# %%
viewer.plot_pLDDT(save=True)

# %%
viewer.plot_pae(save=True)

# %%
viewer.obs["subprotein"] = "nothing"

# %%
viewer.obs.loc[0:488,"subprotein"] = "LacS"
viewer.obs.loc[489:496,"subprotein"] = "Linker"
viewer.obs.loc[497:734,"subprotein"] = "TGP"

# %%
viewer.show_annotation(key= "subprotein")
# Out:
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…

# %%
viewer.show_annotation()
# Out:
# GridspecLayout(children=(Output(layout=Layout(grid_area='widget001')), Output(layout=Layout(grid_area='widget0…
